# %%
import nilearn as nl
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pickle as pkl
import time
import os
import math
from nilearn import plotting
from nilearn import datasets

# %% [markdown]
# ### Data Fetch & Parameters Setting

# %%
data = pkl.load(open( "../data/deepWalk_data_pcp.p", "rb" ))
trn_x = data['trn_x']
trn_y = data['trn_y']
val_x = data['val_x']
val_y = data['val_y']

num_label = trn_y.shape[1]
num_trn = trn_x.shape[0]
num_val = val_x.shape[0]
num_node = 49

print(num_label, num_trn, num_val)
# Out:
# 2 696 175

# %%
#Computation graph params
num_layer = 5
input_size = trn_x.shape[1]
output_size = num_label
num_hidden_units = 2000
dp_rate = 0.0
wd_rate = 0.0005
l_r = 0.0002
num_epoch = 100
batch_size = 20

print(input_size)
# Out:
# 3072

# %%
#Truncate each sample to save only the bottom left part
'''truncated_vector_size = (int)((1+num_node)*num_node/2)
truncated_data = {}
truncated_data['trn_y'] = data['trn_y']
truncated_data['val_y'] = data['val_y']
truncated_data['trn_x'] = np.zeros((num_trn, truncated_vector_size))
truncated_data['val_x'] = np.zeros((num_val, truncated_vector_size))
for i in range(num_trn):
    truncated_trn_x = np.zeros((1, truncated_vector_size))
    start = 0
    for j in range(num_node):
        start = start + j
        truncated_trn_x[0, start:start+j] = data['trn_x'][i, j*num_node : j*num_node + j]
    truncated_data['trn_x'][i, ] = truncated_trn_x

for i in range(num_val):
    truncated_val_x = np.zeros((1, truncated_vector_size))
    start = 0
    for j in range(num_node):
        start = start + j
        truncated_val_x[0, start:start+j] = data['val_x'][i, j*num_node : j*num_node + j]
    truncated_data['val_x'][i, ] = truncated_val_x
    
pkl.dump(truncated_data, open(os.path.join('.', 'truncated_data.p'), 'wb'))'''
# Out:
# "truncated_vector_size = (int)((1+num_node)*num_node/2)\ntruncated_data = {}\ntruncated_data['trn_y'] = data['trn_y']\ntruncated_data['val_y'] = data['val_y']\ntruncated_data['trn_x'] = np.zeros((num_trn, truncated_vector_size))\ntruncated_data['val_x'] = np.zeros((num_val, truncated_vector_size))\nfor i in range(num_trn):\n    truncated_trn_x = np.zeros((1, truncated_vector_size))\n    start = 0\n    for j in range(num_node):\n        start = start + j\n        truncated_trn_x[0, start:start+j] = data['trn_x'][i, j*num_node : j*num_node + j]\n    truncated_data['trn_x'][i, ] = truncated_trn_x\n\nfor i in range(num_val):\n    truncated_val_x = np.zeros((1, truncated_vector_size))\n    start = 0\n    for j in range(num_node):\n        start = start + j\n        truncated_val_x[0, start:start+j] = data['val_x'][i, j*num_node : j*num_node + j]\n    truncated_data['val_x'][i, ] = truncated_val_x\n    \npkl.dump(truncated_data, open(os.path.join('.', 'truncated_data.p'), 'wb'))"

# %%
dataset = datasets.fetch_atlas_harvard_oxford('cort-maxprob-thr25-2mm')
atlas_filename = dataset.maps
labels = dataset.labels

print(trn_y[19])
print(val_y[19])

display = plotting.plot_matrix(trn_x[19].reshape(48, 48), vmin=-1.0, vmax=1.0, colorbar=True, labels=labels[1:])
plotting.show()

display = plotting.plot_matrix(val_x[19].reshape(48, 48), vmin=-1.0, vmax=1.0, colorbar=True, labels=labels[1:])
plotting.show()
# Out:
# [1. 0.]
# [1. 0.]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-124aee16441b> in <module>()
#       6 print(val_y[19])
#       7
# ----> 8 display = plotting.plot_matrix(trn_x[19].reshape(48, 48), vmin=-1.0, vmax=1.0, colorbar=True, labels=labels[1:])
#       9 plotting.show()
#      10
#
# ValueError: cannot reshape array of size 3072 into shape (48,48)

# %% [markdown]
# ### Build Computation Graph

# %%
def forward_prop(cur_layer, out_size, dp_rate, is_input):
    
    _, cur_size = [item.value for item in cur_layer.shape]
        
    var = 2.0 / (cur_size + out_size)

    stddev = math.sqrt(var)

    print("steddev is", stddev)
    print(out_size)

    with tf.name_scope('fc'):
        W_fc = tf.Variable(tf.truncated_normal(shape=[cur_size,out_size], stddev=stddev))
        b_fc = tf.Variable(tf.constant(0.0, shape=[out_size]))
        if is_input is False: 
            cur_layer = tf.nn.dropout(cur_layer, 1 - dp_rate)
        out_layer = tf.matmul(cur_layer, W_fc) + b_fc

    return out_layer

def activation(cur_layer, is_output=False):
    if is_output is True:
        return tf.nn.sigmoid(cur_layer)
    return tf.nn.leaky_relu(cur_layer)

def loss_function(yhat, y):
    '''
    '''
    # get the weight decay terms
    with tf.name_scope('wd_term'):
        wght_params = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES, scope='fc')
        wd_term = wd_rate * tf.stack([tf.nn.l2_loss(i) for i in wght_params])

    with tf.name_scope('crit_loss'):
        crit = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=yhat)) + tf.reduce_sum(wd_term)

    return crit

def generate_dataset(x, y, shuffle=True):
    with tf.name_scope('dataset'):
        dataset = tf.data.Dataset.from_tensor_slices((x, y))
        if shuffle: 
            dataset = dataset.shuffle(buffer_size=1024).batch(batch_size)
        else:
            dataset = dataset.batch(batch_size)

    return dataset.make_initializable_iterator()

# %%
#Build the actual graph
tf.reset_default_graph()
x_place = tf.placeholder('float', [None, input_size], name='input_x')
y_place = tf.placeholder('float', [None,  output_size], name='target_y')
dp_place = tf.placeholder(tf.float32, name='dropout_value')

cur_layer = x_place

for i in range(num_layer):
    print(i)
    if i != (num_layer - 1):
        print(cur_layer.shape)
        cur_layer = forward_prop(cur_layer, num_hidden_units, dp_place, i == 0)
        cur_layer = activation(cur_layer)
    else:
        cur_layer = forward_prop(cur_layer, output_size, dp_place, i == 0)
        yhat_op = activation(cur_layer, True)

#Cross entropy loss
loss_op = loss_function(yhat_op, y_place)
tf.summary.scalar('Cross_Entropy_Loss', loss_op)

#adam
optimizer = tf.train.AdamOptimizer(l_r)
train_op = optimizer.minimize(loss_op)

#Accuracy
correct_pred = tf.equal(tf.argmax(y_place, 1), tf.argmax(yhat_op, 1))  
acc_op = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
tf.summary.scalar('Accuracy', acc_op)

#Iterators
trn_it = generate_dataset(trn_x, trn_y, shuffle=True)
val_it = generate_dataset(val_x, val_y, shuffle=False)
# Out:
# 0
# (?, 3072)
# steddev is 0.01985753676973844
# 2000
# 1
# (?, 2000)
# steddev is 0.022360679774997897
# 2000
# 2
# (?, 2000)
# steddev is 0.022360679774997897
# 2000
# 3
# (?, 2000)
# steddev is 0.022360679774997897
# 2000
# 4
# steddev is 0.0316069770620507
# 2

# %%
#Actual train loop
if 'session' in locals() and session is not None:
    print('Close interactive session', flush=True)
    session.close()


sess = tf.Session()

# get the summary ready
merged = tf.summary.merge_all()
trn_writer = tf.summary.FileWriter("./log", sess.graph)

saver = tf.train.Saver()
sess.run(tf.global_variables_initializer())

# tracing the loss along the way
meta_info = {}
meta_info['trn_loss'] = []
meta_info['trn_acc'] = []
meta_info['val_loss'] = []
meta_info['val_acc'] = []
meta_info['tst_loss'] = []
meta_info['tst_acc'] = []
iteration = 0
  
for ep in range(num_epoch):
    sess.run(trn_it.initializer)
    sess.run(val_it.initializer)

    trn_next_batch = trn_it.get_next()

    avg_trn_loss = 0
    avg_trn_acc = 0
    print('TRN:', flush=True)
    while True: # loop to iterate over training set
        try: 
            x, y = sess.run(trn_next_batch)
        except: 
            break
        print('+', end='', flush=True)
        iteration += 1
        this_batch_size = x.shape[0]


        _, loss_i, acc_i, summary_i, _yhat, _pred = sess.run([train_op, loss_op, acc_op, merged, yhat_op, correct_pred], 
                                                   feed_dict={x_place:x, y_place:y, dp_place:dp_rate})

        trn_writer.add_summary(summary_i, iteration)
        avg_trn_loss = avg_trn_loss + loss_i*this_batch_size
        avg_trn_acc = avg_trn_acc + acc_i*this_batch_size
        
        '''print(_yhat, flush=True)
        print(y, flush=True)
        print(_pred, flush=True)
        print(acc_i, flush=True)'''
    
    avg_trn_loss = avg_trn_loss/num_trn
    avg_trn_acc = avg_trn_acc/num_trn
    
    #Validation
    avg_val_loss = 0
    avg_val_acc = 0
    print('VAL:', flush=True)
    # evaluate the loss and accuracy
    pred_and_gt = {}
    pred_and_gt['x'] = []
    pred_and_gt['y'] = []
    pred_and_gt['yhat'] = []
    
    val_next_batch = val_it.get_next()

    while True:
        try: x, y = sess.run(val_next_batch)
        except: break
        print('+', end='', flush=True)
        this_batch_size = x.shape[0]
        # compute the loss
        _yhat, _loss, _acc = sess.run([yhat_op, loss_op, acc_op], 
                                   feed_dict={x_place:x, y_place:y, dp_place:0.0})

        # keep track of the loss/pred_and_gt
        pred_and_gt['x'].append(x)
        pred_and_gt['y'].append(y)
        pred_and_gt['yhat'].append(_yhat)
        avg_val_loss = avg_val_loss + _loss*this_batch_size
        avg_val_acc = avg_val_acc + _acc*this_batch_size
    
    avg_val_loss = avg_val_loss/num_val
    avg_val_acc = avg_val_acc/num_val

    print('', flush=True)

    # concatenate the list to numpy array
    for k, v in pred_and_gt.items():
        pred_and_gt[k] = np.concatenate(v)
    
    
    print('\nEp.%05d - TRN: loss %.2f VAL: loss %.2f' % (ep, avg_trn_loss, avg_val_loss), flush=True)
    print('\nEp.%05d - TRN: acc %.2f VAL: acc %.2f' % (ep, avg_trn_acc, avg_val_acc), flush=True)
        
        
    # save learning meta information
    meta_info['trn_loss'].append(avg_trn_loss)
    meta_info['trn_acc'].append(avg_trn_acc)
    meta_info['val_loss'].append(avg_val_loss)
    meta_info['val_acc'].append(avg_val_acc)
    
pkl.dump(meta_info, open(os.path.join('.', 'result.p'), 'wb'))
saver.save(sess, "./model/model")
sess.close()
# Out:
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00000 - TRN: loss 2.08 VAL: loss 1.85
#
# Ep.00000 - TRN: acc 0.53 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00001 - TRN: loss 1.67 VAL: loss 1.61
#
# Ep.00001 - TRN: acc 0.60 VAL: acc 0.47
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00002 - TRN: loss 1.39 VAL: loss 1.43
#
# Ep.00002 - TRN: acc 0.67 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00003 - TRN: loss 1.17 VAL: loss 1.37
#
# Ep.00003 - TRN: acc 0.74 VAL: acc 0.46
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00004 - TRN: loss 1.05 VAL: loss 1.24
#
# Ep.00004 - TRN: acc 0.77 VAL: acc 0.52
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00005 - TRN: loss 0.96 VAL: loss 1.19
#
# Ep.00005 - TRN: acc 0.80 VAL: acc 0.55
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00006 - TRN: loss 0.91 VAL: loss 1.20
#
# Ep.00006 - TRN: acc 0.81 VAL: acc 0.47
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00007 - TRN: loss 0.83 VAL: loss 1.15
#
# Ep.00007 - TRN: acc 0.85 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00008 - TRN: loss 0.79 VAL: loss 1.13
#
# Ep.00008 - TRN: acc 0.87 VAL: acc 0.51
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00009 - TRN: loss 0.75 VAL: loss 1.16
#
# Ep.00009 - TRN: acc 0.89 VAL: acc 0.47
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00010 - TRN: loss 0.73 VAL: loss 1.07
#
# Ep.00010 - TRN: acc 0.89 VAL: acc 0.54
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00011 - TRN: loss 0.69 VAL: loss 1.06
#
# Ep.00011 - TRN: acc 0.92 VAL: acc 0.56
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00012 - TRN: loss 0.67 VAL: loss 1.05
#
# Ep.00012 - TRN: acc 0.94 VAL: acc 0.54
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00013 - TRN: loss 0.65 VAL: loss 1.02
#
# Ep.00013 - TRN: acc 0.94 VAL: acc 0.56
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00014 - TRN: loss 0.67 VAL: loss 1.06
#
# Ep.00014 - TRN: acc 0.91 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00015 - TRN: loss 0.64 VAL: loss 1.05
#
# Ep.00015 - TRN: acc 0.93 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00016 - TRN: loss 0.63 VAL: loss 1.04
#
# Ep.00016 - TRN: acc 0.93 VAL: acc 0.51
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00017 - TRN: loss 0.62 VAL: loss 1.06
#
# Ep.00017 - TRN: acc 0.94 VAL: acc 0.47
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00018 - TRN: loss 0.58 VAL: loss 1.05
#
# Ep.00018 - TRN: acc 0.97 VAL: acc 0.47
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00019 - TRN: loss 0.58 VAL: loss 1.03
#
# Ep.00019 - TRN: acc 0.96 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00020 - TRN: loss 0.58 VAL: loss 0.99
#
# Ep.00020 - TRN: acc 0.96 VAL: acc 0.55
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00021 - TRN: loss 0.56 VAL: loss 1.02
#
# Ep.00021 - TRN: acc 0.97 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00022 - TRN: loss 0.56 VAL: loss 1.00
#
# Ep.00022 - TRN: acc 0.97 VAL: acc 0.51
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00023 - TRN: loss 0.55 VAL: loss 0.97
#
# Ep.00023 - TRN: acc 0.96 VAL: acc 0.54
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00024 - TRN: loss 0.57 VAL: loss 0.99
#
# Ep.00024 - TRN: acc 0.93 VAL: acc 0.51
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00025 - TRN: loss 0.56 VAL: loss 1.01
#
# Ep.00025 - TRN: acc 0.94 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00026 - TRN: loss 0.54 VAL: loss 1.01
#
# Ep.00026 - TRN: acc 0.96 VAL: acc 0.46
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00027 - TRN: loss 0.52 VAL: loss 0.97
#
# Ep.00027 - TRN: acc 0.98 VAL: acc 0.51
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00028 - TRN: loss 0.52 VAL: loss 0.98
#
# Ep.00028 - TRN: acc 0.96 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00029 - TRN: loss 0.50 VAL: loss 0.98
#
# Ep.00029 - TRN: acc 0.98 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00030 - TRN: loss 0.50 VAL: loss 1.00
#
# Ep.00030 - TRN: acc 0.98 VAL: acc 0.46
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00031 - TRN: loss 0.50 VAL: loss 1.01
#
# Ep.00031 - TRN: acc 0.98 VAL: acc 0.46
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00032 - TRN: loss 0.51 VAL: loss 0.99
#
# Ep.00032 - TRN: acc 0.96 VAL: acc 0.48
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00033 - TRN: loss 0.52 VAL: loss 0.98
#
# Ep.00033 - TRN: acc 0.95 VAL: acc 0.47
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00034 - TRN: loss 0.52 VAL: loss 0.95
#
# Ep.00034 - TRN: acc 0.95 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00035 - TRN: loss 0.50 VAL: loss 0.98
#
# Ep.00035 - TRN: acc 0.96 VAL: acc 0.47
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00036 - TRN: loss 0.50 VAL: loss 0.96
#
# Ep.00036 - TRN: acc 0.97 VAL: acc 0.48
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00037 - TRN: loss 0.49 VAL: loss 0.94
#
# Ep.00037 - TRN: acc 0.96 VAL: acc 0.51
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00038 - TRN: loss 0.50 VAL: loss 0.94
#
# Ep.00038 - TRN: acc 0.96 VAL: acc 0.51
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00039 - TRN: loss 0.49 VAL: loss 0.94
#
# Ep.00039 - TRN: acc 0.97 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00040 - TRN: loss 0.47 VAL: loss 0.94
#
# Ep.00040 - TRN: acc 0.98 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00041 - TRN: loss 0.47 VAL: loss 0.93
#
# Ep.00041 - TRN: acc 0.98 VAL: acc 0.51
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00042 - TRN: loss 0.47 VAL: loss 0.95
#
# Ep.00042 - TRN: acc 0.98 VAL: acc 0.48
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00043 - TRN: loss 0.46 VAL: loss 0.95
#
# Ep.00043 - TRN: acc 0.98 VAL: acc 0.47
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00044 - TRN: loss 0.46 VAL: loss 0.93
#
# Ep.00044 - TRN: acc 0.98 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00045 - TRN: loss 0.46 VAL: loss 0.91
#
# Ep.00045 - TRN: acc 0.98 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00046 - TRN: loss 0.44 VAL: loss 0.94
#
# Ep.00046 - TRN: acc 0.99 VAL: acc 0.47
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00047 - TRN: loss 0.44 VAL: loss 0.91
#
# Ep.00047 - TRN: acc 0.99 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00048 - TRN: loss 0.44 VAL: loss 0.92
#
# Ep.00048 - TRN: acc 0.99 VAL: acc 0.48
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00049 - TRN: loss 0.43 VAL: loss 0.95
#
# Ep.00049 - TRN: acc 0.99 VAL: acc 0.45
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00050 - TRN: loss 0.43 VAL: loss 0.92
#
# Ep.00050 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00051 - TRN: loss 0.43 VAL: loss 0.91
#
# Ep.00051 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00052 - TRN: loss 0.42 VAL: loss 0.90
#
# Ep.00052 - TRN: acc 0.99 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00053 - TRN: loss 0.42 VAL: loss 0.90
#
# Ep.00053 - TRN: acc 0.99 VAL: acc 0.51
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00054 - TRN: loss 0.42 VAL: loss 0.89
#
# Ep.00054 - TRN: acc 0.99 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00055 - TRN: loss 0.41 VAL: loss 0.89
#
# Ep.00055 - TRN: acc 0.99 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00056 - TRN: loss 0.41 VAL: loss 0.89
#
# Ep.00056 - TRN: acc 0.99 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00057 - TRN: loss 0.41 VAL: loss 0.88
#
# Ep.00057 - TRN: acc 0.99 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00058 - TRN: loss 0.40 VAL: loss 0.88
#
# Ep.00058 - TRN: acc 0.99 VAL: acc 0.51
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00059 - TRN: loss 0.40 VAL: loss 0.88
#
# Ep.00059 - TRN: acc 0.99 VAL: acc 0.51
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00060 - TRN: loss 0.40 VAL: loss 0.87
#
# Ep.00060 - TRN: acc 0.99 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00061 - TRN: loss 0.40 VAL: loss 0.87
#
# Ep.00061 - TRN: acc 0.99 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00062 - TRN: loss 0.40 VAL: loss 0.87
#
# Ep.00062 - TRN: acc 0.99 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00063 - TRN: loss 0.39 VAL: loss 0.87
#
# Ep.00063 - TRN: acc 0.99 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00064 - TRN: loss 0.39 VAL: loss 0.86
#
# Ep.00064 - TRN: acc 0.99 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00065 - TRN: loss 0.39 VAL: loss 0.86
#
# Ep.00065 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00066 - TRN: loss 0.39 VAL: loss 0.86
#
# Ep.00066 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00067 - TRN: loss 0.39 VAL: loss 0.85
#
# Ep.00067 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00068 - TRN: loss 0.38 VAL: loss 0.85
#
# Ep.00068 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00069 - TRN: loss 0.38 VAL: loss 0.85
#
# Ep.00069 - TRN: acc 0.99 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00070 - TRN: loss 0.38 VAL: loss 0.84
#
# Ep.00070 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00071 - TRN: loss 0.38 VAL: loss 0.84
#
# Ep.00071 - TRN: acc 0.99 VAL: acc 0.47
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00072 - TRN: loss 0.38 VAL: loss 0.84
#
# Ep.00072 - TRN: acc 0.99 VAL: acc 0.48
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00073 - TRN: loss 0.37 VAL: loss 0.84
#
# Ep.00073 - TRN: acc 0.99 VAL: acc 0.47
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00074 - TRN: loss 0.37 VAL: loss 0.84
#
# Ep.00074 - TRN: acc 0.99 VAL: acc 0.48
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00075 - TRN: loss 0.37 VAL: loss 0.83
#
# Ep.00075 - TRN: acc 0.99 VAL: acc 0.48
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00076 - TRN: loss 0.37 VAL: loss 0.83
#
# Ep.00076 - TRN: acc 0.99 VAL: acc 0.48
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00077 - TRN: loss 0.37 VAL: loss 0.83
#
# Ep.00077 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00078 - TRN: loss 0.37 VAL: loss 0.83
#
# Ep.00078 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00079 - TRN: loss 0.37 VAL: loss 0.83
#
# Ep.00079 - TRN: acc 0.99 VAL: acc 0.48
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00080 - TRN: loss 0.36 VAL: loss 0.82
#
# Ep.00080 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00081 - TRN: loss 0.36 VAL: loss 0.82
#
# Ep.00081 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00082 - TRN: loss 0.36 VAL: loss 0.82
#
# Ep.00082 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00083 - TRN: loss 0.36 VAL: loss 0.82
#
# Ep.00083 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00084 - TRN: loss 0.36 VAL: loss 0.82
#
# Ep.00084 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00085 - TRN: loss 0.36 VAL: loss 0.82
#
# Ep.00085 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00086 - TRN: loss 0.36 VAL: loss 0.81
#
# Ep.00086 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00087 - TRN: loss 0.36 VAL: loss 0.81
#
# Ep.00087 - TRN: acc 0.99 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00088 - TRN: loss 0.36 VAL: loss 0.81
#
# Ep.00088 - TRN: acc 0.99 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00089 - TRN: loss 0.35 VAL: loss 0.81
#
# Ep.00089 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00090 - TRN: loss 0.35 VAL: loss 0.81
#
# Ep.00090 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00091 - TRN: loss 0.35 VAL: loss 0.81
#
# Ep.00091 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00092 - TRN: loss 0.35 VAL: loss 0.81
#
# Ep.00092 - TRN: acc 0.99 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00093 - TRN: loss 0.35 VAL: loss 0.80
#
# Ep.00093 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00094 - TRN: loss 0.35 VAL: loss 0.80
#
# Ep.00094 - TRN: acc 0.99 VAL: acc 0.50
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00095 - TRN: loss 0.35 VAL: loss 0.80
#
# Ep.00095 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00096 - TRN: loss 0.35 VAL: loss 0.80
#
# Ep.00096 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00097 - TRN: loss 0.35 VAL: loss 0.80
#
# Ep.00097 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00098 - TRN: loss 0.35 VAL: loss 0.80
#
# Ep.00098 - TRN: acc 0.99 VAL: acc 0.49
# TRN:
# +++++++++++++++++++++++++++++++++++VAL:
# +++++++++
#
# Ep.00099 - TRN: loss 0.35 VAL: loss 0.80
#
# Ep.00099 - TRN: acc 0.99 VAL: acc 0.50

# %%
tf.reset_default_graph()

imported_graph = tf.train.import_meta_graph('./model/model.meta')

for tensor in tf.get_default_graph().get_operations():
    print (tensor.name)

test_x = np.zeros((1, 2304))
test_x[0, :] = val_x[45]

with tf.Session() as sess:
    imported_graph.restore(sess, './model/model')
    yhat = sess.run(['Sigmoid:0'], feed_dict={'input_x:0':test_x, 'dropout_value:0':0.0})
    print(yhat)

print(val_y[45])
# Out:
# input_x
# target_y
# dropout_value
# fc/truncated_normal/shape
# fc/truncated_normal/mean
# fc/truncated_normal/stddev
# fc/truncated_normal/TruncatedNormal
# fc/truncated_normal/mul
# fc/truncated_normal
# fc/Variable
# fc/Variable/Assign
# fc/Variable/read
# fc/Const
# fc/Variable_1
# fc/Variable_1/Assign
# fc/Variable_1/read
# fc/MatMul
# fc/add
# LeakyRelu/alpha
# LeakyRelu/mul
# LeakyRelu/Maximum
# fc_1/truncated_normal/shape
# fc_1/truncated_normal/mean
# fc_1/truncated_normal/stddev
# fc_1/truncated_normal/TruncatedNormal
# fc_1/truncated_normal/mul
# fc_1/truncated_normal
# fc_1/Variable
# fc_1/Variable/Assign
# fc_1/Variable/read
# fc_1/Const
# fc_1/Variable_1
# fc_1/Variable_1/Assign
# fc_1/Variable_1/read
# fc_1/sub/x
# fc_1/sub
# fc_1/dropout/Shape
# fc_1/dropout/random_uniform/min
# fc_1/dropout/random_uniform/max
# fc_1/dropout/random_uniform/RandomUniform
# fc_1/dropout/random_uniform/sub
# fc_1/dropout/random_uniform/mul
# fc_1/dropout/random_uniform
# fc_1/dropout/add
# fc_1/dropout/Floor
# fc_1/dropout/div
# fc_1/dropout/mul
# fc_1/MatMul
# fc_1/add
# LeakyRelu_1/alpha
# LeakyRelu_1/mul
# LeakyRelu_1/Maximum
# fc_2/truncated_normal/shape
# fc_2/truncated_normal/mean
# fc_2/truncated_normal/stddev
# fc_2/truncated_normal/TruncatedNormal
# fc_2/truncated_normal/mul
# fc_2/truncated_normal
# fc_2/Variable
# fc_2/Variable/Assign
# fc_2/Variable/read
# fc_2/Const
# fc_2/Variable_1
# fc_2/Variable_1/Assign
# fc_2/Variable_1/read
# fc_2/sub/x
# fc_2/sub
# fc_2/dropout/Shape
# fc_2/dropout/random_uniform/min
# fc_2/dropout/random_uniform/max
# fc_2/dropout/random_uniform/RandomUniform
# fc_2/dropout/random_uniform/sub
# fc_2/dropout/random_uniform/mul
# fc_2/dropout/random_uniform
# fc_2/dropout/add
# fc_2/dropout/Floor
# fc_2/dropout/div
# fc_2/dropout/mul
# fc_2/MatMul
# fc_2/add
# LeakyRelu_2/alpha
# LeakyRelu_2/mul
# LeakyRelu_2/Maximum
# fc_3/truncated_normal/shape
# fc_3/truncated_normal/mean
# fc_3/truncated_normal/stddev
# fc_3/truncated_normal/TruncatedNormal
# fc_3/truncated_normal/mul
# fc_3/truncated_normal
# fc_3/Variable
# fc_3/Variable/Assign
# fc_3/Variable/read
# fc_3/Const
# fc_3/Variable_1
# fc_3/Variable_1/Assign
# fc_3/Variable_1/read
# fc_3/sub/x
# fc_3/sub
# fc_3/dropout/Shape
# fc_3/dropout/random_uniform/min
# fc_3/dropout/random_uniform/max
# fc_3/dropout/random_uniform/RandomUniform
# fc_3/dropout/random_uniform/sub
# fc_3/dropout/random_uniform/mul
# fc_3/dropout/random_uniform
# fc_3/dropout/add
# fc_3/dropout/Floor
# fc_3/dropout/div
# fc_3/dropout/mul
# fc_3/MatMul
# fc_3/add
# LeakyRelu_3/alpha
# LeakyRelu_3/mul
# LeakyRelu_3/Maximum
# fc_4/truncated_normal/shape
# fc_4/truncated_normal/mean
# fc_4/truncated_normal/stddev
# fc_4/truncated_normal/TruncatedNormal
# fc_4/truncated_normal/mul
# fc_4/truncated_normal
# fc_4/Variable
# fc_4/Variable/Assign
# fc_4/Variable/read
# fc_4/Const
# fc_4/Variable_1
# fc_4/Variable_1/Assign
# fc_4/Variable_1/read
# fc_4/sub/x
# fc_4/sub
# fc_4/dropout/Shape
# fc_4/dropout/random_uniform/min
# fc_4/dropout/random_uniform/max
# fc_4/dropout/random_uniform/RandomUniform
# fc_4/dropout/random_uniform/sub
# fc_4/dropout/random_uniform/mul
# fc_4/dropout/random_uniform
# fc_4/dropout/add
# fc_4/dropout/Floor
# fc_4/dropout/div
# fc_4/dropout/mul
# fc_4/MatMul
# fc_4/add
# Sigmoid
# wd_term/L2Loss
# wd_term/L2Loss_1
# wd_term/L2Loss_2
# wd_term/L2Loss_3
# wd_term/L2Loss_4
# wd_term/L2Loss_5
# wd_term/L2Loss_6
# wd_term/L2Loss_7
# wd_term/L2Loss_8
# wd_term/L2Loss_9
# wd_term/stack
# wd_term/mul/x
# wd_term/mul
# crit_loss/Rank
# crit_loss/Shape
# crit_loss/Rank_1
# crit_loss/Shape_1
# crit_loss/Sub/y
# crit_loss/Sub
# crit_loss/Slice/begin
# crit_loss/Slice/size
# crit_loss/Slice
# crit_loss/concat/values_0
# crit_loss/concat/axis
# crit_loss/concat
# crit_loss/Reshape
# crit_loss/Rank_2
# crit_loss/Shape_2
# crit_loss/Sub_1/y
# crit_loss/Sub_1
# crit_loss/Slice_1/begin
# crit_loss/Slice_1/size
# crit_loss/Slice_1
# crit_loss/concat_1/values_0
# crit_loss/concat_1/axis
# crit_loss/concat_1
# crit_loss/Reshape_1
# crit_loss/SoftmaxCrossEntropyWithLogits
# crit_loss/Sub_2/y
# crit_loss/Sub_2
# crit_loss/Slice_2/begin
# crit_loss/Slice_2/size
# crit_loss/Slice_2
# crit_loss/Reshape_2
# crit_loss/Const
# crit_loss/Mean
# crit_loss/Const_1
# crit_loss/Sum
# crit_loss/add
# Cross_Entropy_Loss/tags
# Cross_Entropy_Loss
# gradients/Shape
# gradients/Const
# gradients/Fill
# gradients/crit_loss/add_grad/Shape
# gradients/crit_loss/add_grad/Shape_1
# gradients/crit_loss/add_grad/BroadcastGradientArgs
# gradients/crit_loss/add_grad/Sum
# gradients/crit_loss/add_grad/Reshape
# gradients/crit_loss/add_grad/Sum_1
# gradients/crit_loss/add_grad/Reshape_1
# gradients/crit_loss/add_grad/tuple/group_deps
# gradients/crit_loss/add_grad/tuple/control_dependency
# gradients/crit_loss/add_grad/tuple/control_dependency_1
# gradients/crit_loss/Mean_grad/Reshape/shape
# gradients/crit_loss/Mean_grad/Reshape
# gradients/crit_loss/Mean_grad/Shape
# gradients/crit_loss/Mean_grad/Tile
# gradients/crit_loss/Mean_grad/Shape_1
# gradients/crit_loss/Mean_grad/Shape_2
# gradients/crit_loss/Mean_grad/Const
# gradients/crit_loss/Mean_grad/Prod
# gradients/crit_loss/Mean_grad/Const_1
# gradients/crit_loss/Mean_grad/Prod_1
# gradients/crit_loss/Mean_grad/Maximum/y
# gradients/crit_loss/Mean_grad/Maximum
# gradients/crit_loss/Mean_grad/floordiv
# gradients/crit_loss/Mean_grad/Cast
# gradients/crit_loss/Mean_grad/truediv
# gradients/crit_loss/Sum_grad/Reshape/shape
# gradients/crit_loss/Sum_grad/Reshape
# gradients/crit_loss/Sum_grad/Tile/multiples
# gradients/crit_loss/Sum_grad/Tile
# gradients/crit_loss/Reshape_2_grad/Shape
# gradients/crit_loss/Reshape_2_grad/Reshape
# gradients/wd_term/mul_grad/Shape
# gradients/wd_term/mul_grad/Shape_1
# gradients/wd_term/mul_grad/BroadcastGradientArgs
# gradients/wd_term/mul_grad/mul
# gradients/wd_term/mul_grad/Sum
# gradients/wd_term/mul_grad/Reshape
# gradients/wd_term/mul_grad/mul_1
# gradients/wd_term/mul_grad/Sum_1
# gradients/wd_term/mul_grad/Reshape_1
# gradients/wd_term/mul_grad/tuple/group_deps
# gradients/wd_term/mul_grad/tuple/control_dependency
# gradients/wd_term/mul_grad/tuple/control_dependency_1
# gradients/zeros_like
# gradients/crit_loss/SoftmaxCrossEntropyWithLogits_grad/ExpandDims/dim
# gradients/crit_loss/SoftmaxCrossEntropyWithLogits_grad/ExpandDims
# gradients/crit_loss/SoftmaxCrossEntropyWithLogits_grad/mul
# gradients/wd_term/stack_grad/unstack
# gradients/wd_term/stack_grad/tuple/group_deps
# gradients/wd_term/stack_grad/tuple/control_dependency
# gradients/wd_term/stack_grad/tuple/control_dependency_1
# gradients/wd_term/stack_grad/tuple/control_dependency_2
# gradients/wd_term/stack_grad/tuple/control_dependency_3
# gradients/wd_term/stack_grad/tuple/control_dependency_4
# gradients/wd_term/stack_grad/tuple/control_dependency_5
# gradients/wd_term/stack_grad/tuple/control_dependency_6
# gradients/wd_term/stack_grad/tuple/control_dependency_7
# gradients/wd_term/stack_grad/tuple/control_dependency_8
# gradients/wd_term/stack_grad/tuple/control_dependency_9
# gradients/crit_loss/Reshape_grad/Shape
# gradients/crit_loss/Reshape_grad/Reshape
# gradients/wd_term/L2Loss_grad/mul
# gradients/wd_term/L2Loss_1_grad/mul
# gradients/wd_term/L2Loss_2_grad/mul
# gradients/wd_term/L2Loss_3_grad/mul
# gradients/wd_term/L2Loss_4_grad/mul
# gradients/wd_term/L2Loss_5_grad/mul
# gradients/wd_term/L2Loss_6_grad/mul
# gradients/wd_term/L2Loss_7_grad/mul
# gradients/wd_term/L2Loss_8_grad/mul
# gradients/wd_term/L2Loss_9_grad/mul
# gradients/Sigmoid_grad/SigmoidGrad
# gradients/fc_4/add_grad/Shape
# gradients/fc_4/add_grad/Shape_1
# gradients/fc_4/add_grad/BroadcastGradientArgs
# gradients/fc_4/add_grad/Sum
# gradients/fc_4/add_grad/Reshape
# gradients/fc_4/add_grad/Sum_1
# gradients/fc_4/add_grad/Reshape_1
# gradients/fc_4/add_grad/tuple/group_deps
# gradients/fc_4/add_grad/tuple/control_dependency
# gradients/fc_4/add_grad/tuple/control_dependency_1
# gradients/fc_4/MatMul_grad/MatMul
# gradients/fc_4/MatMul_grad/MatMul_1
# gradients/fc_4/MatMul_grad/tuple/group_deps
# gradients/fc_4/MatMul_grad/tuple/control_dependency
# gradients/fc_4/MatMul_grad/tuple/control_dependency_1
# gradients/AddN
# gradients/fc_4/dropout/mul_grad/Shape
# gradients/fc_4/dropout/mul_grad/Shape_1
# gradients/fc_4/dropout/mul_grad/BroadcastGradientArgs
# gradients/fc_4/dropout/mul_grad/mul
# gradients/fc_4/dropout/mul_grad/Sum
# gradients/fc_4/dropout/mul_grad/Reshape
# gradients/fc_4/dropout/mul_grad/mul_1
# gradients/fc_4/dropout/mul_grad/Sum_1
# gradients/fc_4/dropout/mul_grad/Reshape_1
# gradients/fc_4/dropout/mul_grad/tuple/group_deps
# gradients/fc_4/dropout/mul_grad/tuple/control_dependency
# gradients/fc_4/dropout/mul_grad/tuple/control_dependency_1
# gradients/AddN_1
# gradients/fc_4/dropout/div_grad/Shape
# gradients/fc_4/dropout/div_grad/Shape_1
# gradients/fc_4/dropout/div_grad/BroadcastGradientArgs
# gradients/fc_4/dropout/div_grad/RealDiv
# gradients/fc_4/dropout/div_grad/Sum
# gradients/fc_4/dropout/div_grad/Reshape
# gradients/fc_4/dropout/div_grad/Neg
# gradients/fc_4/dropout/div_grad/RealDiv_1
# gradients/fc_4/dropout/div_grad/RealDiv_2
# gradients/fc_4/dropout/div_grad/mul
# gradients/fc_4/dropout/div_grad/Sum_1
# gradients/fc_4/dropout/div_grad/Reshape_1
# gradients/fc_4/dropout/div_grad/tuple/group_deps
# gradients/fc_4/dropout/div_grad/tuple/control_dependency
# gradients/fc_4/dropout/div_grad/tuple/control_dependency_1
# gradients/LeakyRelu_3/Maximum_grad/Shape
# gradients/LeakyRelu_3/Maximum_grad/Shape_1
# gradients/LeakyRelu_3/Maximum_grad/Shape_2
# gradients/LeakyRelu_3/Maximum_grad/zeros/Const
# gradients/LeakyRelu_3/Maximum_grad/zeros
# gradients/LeakyRelu_3/Maximum_grad/GreaterEqual
# gradients/LeakyRelu_3/Maximum_grad/BroadcastGradientArgs
# gradients/LeakyRelu_3/Maximum_grad/Select
# gradients/LeakyRelu_3/Maximum_grad/Select_1
# gradients/LeakyRelu_3/Maximum_grad/Sum
# gradients/LeakyRelu_3/Maximum_grad/Reshape
# gradients/LeakyRelu_3/Maximum_grad/Sum_1
# gradients/LeakyRelu_3/Maximum_grad/Reshape_1
# gradients/LeakyRelu_3/Maximum_grad/tuple/group_deps
# gradients/LeakyRelu_3/Maximum_grad/tuple/control_dependency
# gradients/LeakyRelu_3/Maximum_grad/tuple/control_dependency_1
# gradients/LeakyRelu_3/mul_grad/Shape
# gradients/LeakyRelu_3/mul_grad/Shape_1
# gradients/LeakyRelu_3/mul_grad/BroadcastGradientArgs
# gradients/LeakyRelu_3/mul_grad/mul
# gradients/LeakyRelu_3/mul_grad/Sum
# gradients/LeakyRelu_3/mul_grad/Reshape
# gradients/LeakyRelu_3/mul_grad/mul_1
# gradients/LeakyRelu_3/mul_grad/Sum_1
# gradients/LeakyRelu_3/mul_grad/Reshape_1
# gradients/LeakyRelu_3/mul_grad/tuple/group_deps
# gradients/LeakyRelu_3/mul_grad/tuple/control_dependency
# gradients/LeakyRelu_3/mul_grad/tuple/control_dependency_1
# gradients/AddN_2
# gradients/fc_3/add_grad/Shape
# gradients/fc_3/add_grad/Shape_1
# gradients/fc_3/add_grad/BroadcastGradientArgs
# gradients/fc_3/add_grad/Sum
# gradients/fc_3/add_grad/Reshape
# gradients/fc_3/add_grad/Sum_1
# gradients/fc_3/add_grad/Reshape_1
# gradients/fc_3/add_grad/tuple/group_deps
# gradients/fc_3/add_grad/tuple/control_dependency
# gradients/fc_3/add_grad/tuple/control_dependency_1
# gradients/fc_3/MatMul_grad/MatMul
# gradients/fc_3/MatMul_grad/MatMul_1
# gradients/fc_3/MatMul_grad/tuple/group_deps
# gradients/fc_3/MatMul_grad/tuple/control_dependency
# gradients/fc_3/MatMul_grad/tuple/control_dependency_1
# gradients/AddN_3
# gradients/fc_3/dropout/mul_grad/Shape
# gradients/fc_3/dropout/mul_grad/Shape_1
# gradients/fc_3/dropout/mul_grad/BroadcastGradientArgs
# gradients/fc_3/dropout/mul_grad/mul
# gradients/fc_3/dropout/mul_grad/Sum
# gradients/fc_3/dropout/mul_grad/Reshape
# gradients/fc_3/dropout/mul_grad/mul_1
# gradients/fc_3/dropout/mul_grad/Sum_1
# gradients/fc_3/dropout/mul_grad/Reshape_1
# gradients/fc_3/dropout/mul_grad/tuple/group_deps
# gradients/fc_3/dropout/mul_grad/tuple/control_dependency
# gradients/fc_3/dropout/mul_grad/tuple/control_dependency_1
# gradients/AddN_4
# gradients/fc_3/dropout/div_grad/Shape
# gradients/fc_3/dropout/div_grad/Shape_1
# gradients/fc_3/dropout/div_grad/BroadcastGradientArgs
# gradients/fc_3/dropout/div_grad/RealDiv
# gradients/fc_3/dropout/div_grad/Sum
# gradients/fc_3/dropout/div_grad/Reshape
# gradients/fc_3/dropout/div_grad/Neg
# gradients/fc_3/dropout/div_grad/RealDiv_1
# gradients/fc_3/dropout/div_grad/RealDiv_2
# gradients/fc_3/dropout/div_grad/mul
# gradients/fc_3/dropout/div_grad/Sum_1
# gradients/fc_3/dropout/div_grad/Reshape_1
# gradients/fc_3/dropout/div_grad/tuple/group_deps
# gradients/fc_3/dropout/div_grad/tuple/control_dependency
# gradients/fc_3/dropout/div_grad/tuple/control_dependency_1
# gradients/LeakyRelu_2/Maximum_grad/Shape
# gradients/LeakyRelu_2/Maximum_grad/Shape_1
# gradients/LeakyRelu_2/Maximum_grad/Shape_2
# gradients/LeakyRelu_2/Maximum_grad/zeros/Const
# gradients/LeakyRelu_2/Maximum_grad/zeros
# gradients/LeakyRelu_2/Maximum_grad/GreaterEqual
# gradients/LeakyRelu_2/Maximum_grad/BroadcastGradientArgs
# gradients/LeakyRelu_2/Maximum_grad/Select
# gradients/LeakyRelu_2/Maximum_grad/Select_1
# gradients/LeakyRelu_2/Maximum_grad/Sum
# gradients/LeakyRelu_2/Maximum_grad/Reshape
# gradients/LeakyRelu_2/Maximum_grad/Sum_1
# gradients/LeakyRelu_2/Maximum_grad/Reshape_1
# gradients/LeakyRelu_2/Maximum_grad/tuple/group_deps
# gradients/LeakyRelu_2/Maximum_grad/tuple/control_dependency
# gradients/LeakyRelu_2/Maximum_grad/tuple/control_dependency_1
# gradients/LeakyRelu_2/mul_grad/Shape
# gradients/LeakyRelu_2/mul_grad/Shape_1
# gradients/LeakyRelu_2/mul_grad/BroadcastGradientArgs
# gradients/LeakyRelu_2/mul_grad/mul
# gradients/LeakyRelu_2/mul_grad/Sum
# gradients/LeakyRelu_2/mul_grad/Reshape
# gradients/LeakyRelu_2/mul_grad/mul_1
# gradients/LeakyRelu_2/mul_grad/Sum_1
# gradients/LeakyRelu_2/mul_grad/Reshape_1
# gradients/LeakyRelu_2/mul_grad/tuple/group_deps
# gradients/LeakyRelu_2/mul_grad/tuple/control_dependency
# gradients/LeakyRelu_2/mul_grad/tuple/control_dependency_1
# gradients/AddN_5
# gradients/fc_2/add_grad/Shape
# gradients/fc_2/add_grad/Shape_1
# gradients/fc_2/add_grad/BroadcastGradientArgs
# gradients/fc_2/add_grad/Sum
# gradients/fc_2/add_grad/Reshape
# gradients/fc_2/add_grad/Sum_1
# gradients/fc_2/add_grad/Reshape_1
# gradients/fc_2/add_grad/tuple/group_deps
# gradients/fc_2/add_grad/tuple/control_dependency
# gradients/fc_2/add_grad/tuple/control_dependency_1
# gradients/fc_2/MatMul_grad/MatMul
# gradients/fc_2/MatMul_grad/MatMul_1
# gradients/fc_2/MatMul_grad/tuple/group_deps
# gradients/fc_2/MatMul_grad/tuple/control_dependency
# gradients/fc_2/MatMul_grad/tuple/control_dependency_1
# gradients/AddN_6
# gradients/fc_2/dropout/mul_grad/Shape
# gradients/fc_2/dropout/mul_grad/Shape_1
# gradients/fc_2/dropout/mul_grad/BroadcastGradientArgs
# gradients/fc_2/dropout/mul_grad/mul
# gradients/fc_2/dropout/mul_grad/Sum
# gradients/fc_2/dropout/mul_grad/Reshape
# gradients/fc_2/dropout/mul_grad/mul_1
# gradients/fc_2/dropout/mul_grad/Sum_1
# gradients/fc_2/dropout/mul_grad/Reshape_1
# gradients/fc_2/dropout/mul_grad/tuple/group_deps
# gradients/fc_2/dropout/mul_grad/tuple/control_dependency
# gradients/fc_2/dropout/mul_grad/tuple/control_dependency_1
# gradients/AddN_7
# gradients/fc_2/dropout/div_grad/Shape
# gradients/fc_2/dropout/div_grad/Shape_1
# gradients/fc_2/dropout/div_grad/BroadcastGradientArgs
# gradients/fc_2/dropout/div_grad/RealDiv
# gradients/fc_2/dropout/div_grad/Sum
# gradients/fc_2/dropout/div_grad/Reshape
# gradients/fc_2/dropout/div_grad/Neg
# gradients/fc_2/dropout/div_grad/RealDiv_1
# gradients/fc_2/dropout/div_grad/RealDiv_2
# gradients/fc_2/dropout/div_grad/mul
# gradients/fc_2/dropout/div_grad/Sum_1
# gradients/fc_2/dropout/div_grad/Reshape_1
# gradients/fc_2/dropout/div_grad/tuple/group_deps
# gradients/fc_2/dropout/div_grad/tuple/control_dependency
# gradients/fc_2/dropout/div_grad/tuple/control_dependency_1
# gradients/LeakyRelu_1/Maximum_grad/Shape
# gradients/LeakyRelu_1/Maximum_grad/Shape_1
# gradients/LeakyRelu_1/Maximum_grad/Shape_2
# gradients/LeakyRelu_1/Maximum_grad/zeros/Const
# gradients/LeakyRelu_1/Maximum_grad/zeros
# gradients/LeakyRelu_1/Maximum_grad/GreaterEqual
# gradients/LeakyRelu_1/Maximum_grad/BroadcastGradientArgs
# gradients/LeakyRelu_1/Maximum_grad/Select
# gradients/LeakyRelu_1/Maximum_grad/Select_1
# gradients/LeakyRelu_1/Maximum_grad/Sum
# gradients/LeakyRelu_1/Maximum_grad/Reshape
# gradients/LeakyRelu_1/Maximum_grad/Sum_1
# gradients/LeakyRelu_1/Maximum_grad/Reshape_1
# gradients/LeakyRelu_1/Maximum_grad/tuple/group_deps
# gradients/LeakyRelu_1/Maximum_grad/tuple/control_dependency
# gradients/LeakyRelu_1/Maximum_grad/tuple/control_dependency_1
# gradients/LeakyRelu_1/mul_grad/Shape
# gradients/LeakyRelu_1/mul_grad/Shape_1
# gradients/LeakyRelu_1/mul_grad/BroadcastGradientArgs
# gradients/LeakyRelu_1/mul_grad/mul
# gradients/LeakyRelu_1/mul_grad/Sum
# gradients/LeakyRelu_1/mul_grad/Reshape
# gradients/LeakyRelu_1/mul_grad/mul_1
# gradients/LeakyRelu_1/mul_grad/Sum_1
# gradients/LeakyRelu_1/mul_grad/Reshape_1
# gradients/LeakyRelu_1/mul_grad/tuple/group_deps
# gradients/LeakyRelu_1/mul_grad/tuple/control_dependency
# gradients/LeakyRelu_1/mul_grad/tuple/control_dependency_1
# gradients/AddN_8
# gradients/fc_1/add_grad/Shape
# gradients/fc_1/add_grad/Shape_1
# gradients/fc_1/add_grad/BroadcastGradientArgs
# gradients/fc_1/add_grad/Sum
# gradients/fc_1/add_grad/Reshape
# gradients/fc_1/add_grad/Sum_1
# gradients/fc_1/add_grad/Reshape_1
# gradients/fc_1/add_grad/tuple/group_deps
# gradients/fc_1/add_grad/tuple/control_dependency
# gradients/fc_1/add_grad/tuple/control_dependency_1
# gradients/fc_1/MatMul_grad/MatMul
# gradients/fc_1/MatMul_grad/MatMul_1
# gradients/fc_1/MatMul_grad/tuple/group_deps
# gradients/fc_1/MatMul_grad/tuple/control_dependency
# gradients/fc_1/MatMul_grad/tuple/control_dependency_1
# gradients/AddN_9
# gradients/fc_1/dropout/mul_grad/Shape
# gradients/fc_1/dropout/mul_grad/Shape_1
# gradients/fc_1/dropout/mul_grad/BroadcastGradientArgs
# gradients/fc_1/dropout/mul_grad/mul
# gradients/fc_1/dropout/mul_grad/Sum
# gradients/fc_1/dropout/mul_grad/Reshape
# gradients/fc_1/dropout/mul_grad/mul_1
# gradients/fc_1/dropout/mul_grad/Sum_1
# gradients/fc_1/dropout/mul_grad/Reshape_1
# gradients/fc_1/dropout/mul_grad/tuple/group_deps
# gradients/fc_1/dropout/mul_grad/tuple/control_dependency
# gradients/fc_1/dropout/mul_grad/tuple/control_dependency_1
# gradients/AddN_10
# gradients/fc_1/dropout/div_grad/Shape
# gradients/fc_1/dropout/div_grad/Shape_1
# gradients/fc_1/dropout/div_grad/BroadcastGradientArgs
# gradients/fc_1/dropout/div_grad/RealDiv
# gradients/fc_1/dropout/div_grad/Sum
# gradients/fc_1/dropout/div_grad/Reshape
# gradients/fc_1/dropout/div_grad/Neg
# gradients/fc_1/dropout/div_grad/RealDiv_1
# gradients/fc_1/dropout/div_grad/RealDiv_2
# gradients/fc_1/dropout/div_grad/mul
# gradients/fc_1/dropout/div_grad/Sum_1
# gradients/fc_1/dropout/div_grad/Reshape_1
# gradients/fc_1/dropout/div_grad/tuple/group_deps
# gradients/fc_1/dropout/div_grad/tuple/control_dependency
# gradients/fc_1/dropout/div_grad/tuple/control_dependency_1
# gradients/LeakyRelu/Maximum_grad/Shape
# gradients/LeakyRelu/Maximum_grad/Shape_1
# gradients/LeakyRelu/Maximum_grad/Shape_2
# gradients/LeakyRelu/Maximum_grad/zeros/Const
# gradients/LeakyRelu/Maximum_grad/zeros
# gradients/LeakyRelu/Maximum_grad/GreaterEqual
# gradients/LeakyRelu/Maximum_grad/BroadcastGradientArgs
# gradients/LeakyRelu/Maximum_grad/Select
# gradients/LeakyRelu/Maximum_grad/Select_1
# gradients/LeakyRelu/Maximum_grad/Sum
# gradients/LeakyRelu/Maximum_grad/Reshape
# gradients/LeakyRelu/Maximum_grad/Sum_1
# gradients/LeakyRelu/Maximum_grad/Reshape_1
# gradients/LeakyRelu/Maximum_grad/tuple/group_deps
# gradients/LeakyRelu/Maximum_grad/tuple/control_dependency
# gradients/LeakyRelu/Maximum_grad/tuple/control_dependency_1
# gradients/LeakyRelu/mul_grad/Shape
# gradients/LeakyRelu/mul_grad/Shape_1
# gradients/LeakyRelu/mul_grad/BroadcastGradientArgs
# gradients/LeakyRelu/mul_grad/mul
# gradients/LeakyRelu/mul_grad/Sum
# gradients/LeakyRelu/mul_grad/Reshape
# gradients/LeakyRelu/mul_grad/mul_1
# gradients/LeakyRelu/mul_grad/Sum_1
# gradients/LeakyRelu/mul_grad/Reshape_1
# gradients/LeakyRelu/mul_grad/tuple/group_deps
# gradients/LeakyRelu/mul_grad/tuple/control_dependency
# gradients/LeakyRelu/mul_grad/tuple/control_dependency_1
# gradients/AddN_11
# gradients/fc/add_grad/Shape
# gradients/fc/add_grad/Shape_1
# gradients/fc/add_grad/BroadcastGradientArgs
# gradients/fc/add_grad/Sum
# gradients/fc/add_grad/Reshape
# gradients/fc/add_grad/Sum_1
# gradients/fc/add_grad/Reshape_1
# gradients/fc/add_grad/tuple/group_deps
# gradients/fc/add_grad/tuple/control_dependency
# gradients/fc/add_grad/tuple/control_dependency_1
# gradients/fc/MatMul_grad/MatMul
# gradients/fc/MatMul_grad/MatMul_1
# gradients/fc/MatMul_grad/tuple/group_deps
# gradients/fc/MatMul_grad/tuple/control_dependency
# gradients/fc/MatMul_grad/tuple/control_dependency_1
# gradients/AddN_12
# gradients/AddN_13
# beta1_power/initial_value
# beta1_power
# beta1_power/Assign
# beta1_power/read
# beta2_power/initial_value
# beta2_power
# beta2_power/Assign
# beta2_power/read
# fc/Variable/Adam/Initializer/zeros
# fc/Variable/Adam
# fc/Variable/Adam/Assign
# fc/Variable/Adam/read
# fc/Variable/Adam_1/Initializer/zeros
# fc/Variable/Adam_1
# fc/Variable/Adam_1/Assign
# fc/Variable/Adam_1/read
# fc/Variable_1/Adam/Initializer/zeros
# fc/Variable_1/Adam
# fc/Variable_1/Adam/Assign
# fc/Variable_1/Adam/read
# fc/Variable_1/Adam_1/Initializer/zeros
# fc/Variable_1/Adam_1
# fc/Variable_1/Adam_1/Assign
# fc/Variable_1/Adam_1/read
# fc_1/Variable/Adam/Initializer/zeros
# fc_1/Variable/Adam
# fc_1/Variable/Adam/Assign
# fc_1/Variable/Adam/read
# fc_1/Variable/Adam_1/Initializer/zeros
# fc_1/Variable/Adam_1
# fc_1/Variable/Adam_1/Assign
# fc_1/Variable/Adam_1/read
# fc_1/Variable_1/Adam/Initializer/zeros
# fc_1/Variable_1/Adam
# fc_1/Variable_1/Adam/Assign
# fc_1/Variable_1/Adam/read
# fc_1/Variable_1/Adam_1/Initializer/zeros
# fc_1/Variable_1/Adam_1
# fc_1/Variable_1/Adam_1/Assign
# fc_1/Variable_1/Adam_1/read
# fc_2/Variable/Adam/Initializer/zeros
# fc_2/Variable/Adam
# fc_2/Variable/Adam/Assign
# fc_2/Variable/Adam/read
# fc_2/Variable/Adam_1/Initializer/zeros
# fc_2/Variable/Adam_1
# fc_2/Variable/Adam_1/Assign
# fc_2/Variable/Adam_1/read
# fc_2/Variable_1/Adam/Initializer/zeros
# fc_2/Variable_1/Adam
# fc_2/Variable_1/Adam/Assign
# fc_2/Variable_1/Adam/read
# fc_2/Variable_1/Adam_1/Initializer/zeros
# fc_2/Variable_1/Adam_1
# fc_2/Variable_1/Adam_1/Assign
# fc_2/Variable_1/Adam_1/read
# fc_3/Variable/Adam/Initializer/zeros
# fc_3/Variable/Adam
# fc_3/Variable/Adam/Assign
# fc_3/Variable/Adam/read
# fc_3/Variable/Adam_1/Initializer/zeros
# fc_3/Variable/Adam_1
# fc_3/Variable/Adam_1/Assign
# fc_3/Variable/Adam_1/read
# fc_3/Variable_1/Adam/Initializer/zeros
# fc_3/Variable_1/Adam
# fc_3/Variable_1/Adam/Assign
# fc_3/Variable_1/Adam/read
# fc_3/Variable_1/Adam_1/Initializer/zeros
# fc_3/Variable_1/Adam_1
# fc_3/Variable_1/Adam_1/Assign
# fc_3/Variable_1/Adam_1/read
# fc_4/Variable/Adam/Initializer/zeros
# fc_4/Variable/Adam
# fc_4/Variable/Adam/Assign
# fc_4/Variable/Adam/read
# fc_4/Variable/Adam_1/Initializer/zeros
# fc_4/Variable/Adam_1
# fc_4/Variable/Adam_1/Assign
# fc_4/Variable/Adam_1/read
# fc_4/Variable_1/Adam/Initializer/zeros
# fc_4/Variable_1/Adam
# fc_4/Variable_1/Adam/Assign
# fc_4/Variable_1/Adam/read
# fc_4/Variable_1/Adam_1/Initializer/zeros
# fc_4/Variable_1/Adam_1
# fc_4/Variable_1/Adam_1/Assign
# fc_4/Variable_1/Adam_1/read
# Adam/learning_rate
# Adam/beta1
# Adam/beta2
# Adam/epsilon
# Adam/update_fc/Variable/ApplyAdam
# Adam/update_fc/Variable_1/ApplyAdam
# Adam/update_fc_1/Variable/ApplyAdam
# Adam/update_fc_1/Variable_1/ApplyAdam
# Adam/update_fc_2/Variable/ApplyAdam
# Adam/update_fc_2/Variable_1/ApplyAdam
# Adam/update_fc_3/Variable/ApplyAdam
# Adam/update_fc_3/Variable_1/ApplyAdam
# Adam/update_fc_4/Variable/ApplyAdam
# Adam/update_fc_4/Variable_1/ApplyAdam
# Adam/mul
# Adam/Assign
# Adam/mul_1
# Adam/Assign_1
# Adam
# ArgMax/dimension
# ArgMax
# ArgMax_1/dimension
# ArgMax_1
# Equal
# Cast
# Const
# Mean
# Accuracy/tags
# Accuracy
# dataset/tensors/component_0
# dataset/tensors/component_1
# dataset/buffer_size
# dataset/seed
# dataset/seed2
# Iterator
# TensorSliceDataset
# ShuffleDataset
# BatchDataset/batch_size
# BatchDataset
# MakeIterator
# dataset_1/tensors/component_0
# dataset_1/tensors/component_1
# Iterator_1
# TensorSliceDataset_1
# BatchDataset_1/batch_size
# BatchDataset_1
# MakeIterator_1
# Merge/MergeSummary
# save/Const
# save/SaveV2/tensor_names
# save/SaveV2/shape_and_slices
# save/SaveV2
# save/control_dependency
# save/RestoreV2/tensor_names
# save/RestoreV2/shape_and_slices
# save/RestoreV2
# save/Assign
# save/RestoreV2_1/tensor_names
# save/RestoreV2_1/shape_and_slices
# save/RestoreV2_1
# save/Assign_1
# save/RestoreV2_2/tensor_names
# save/RestoreV2_2/shape_and_slices
# save/RestoreV2_2
# save/Assign_2
# save/RestoreV2_3/tensor_names
# save/RestoreV2_3/shape_and_slices
# save/RestoreV2_3
# save/Assign_3
# save/RestoreV2_4/tensor_names
# save/RestoreV2_4/shape_and_slices
# save/RestoreV2_4
# save/Assign_4
# save/RestoreV2_5/tensor_names
# save/RestoreV2_5/shape_and_slices
# save/RestoreV2_5
# save/Assign_5
# save/RestoreV2_6/tensor_names
# save/RestoreV2_6/shape_and_slices
# save/RestoreV2_6
# save/Assign_6
# save/RestoreV2_7/tensor_names
# save/RestoreV2_7/shape_and_slices
# save/RestoreV2_7
# save/Assign_7
# save/RestoreV2_8/tensor_names
# save/RestoreV2_8/shape_and_slices
# save/RestoreV2_8
# save/Assign_8
# save/RestoreV2_9/tensor_names
# save/RestoreV2_9/shape_and_slices
# save/RestoreV2_9
# save/Assign_9
# save/RestoreV2_10/tensor_names
# save/RestoreV2_10/shape_and_slices
# save/RestoreV2_10
# save/Assign_10
# save/RestoreV2_11/tensor_names
# save/RestoreV2_11/shape_and_slices
# save/RestoreV2_11
# save/Assign_11
# save/RestoreV2_12/tensor_names
# save/RestoreV2_12/shape_and_slices
# save/RestoreV2_12
# save/Assign_12
# save/RestoreV2_13/tensor_names
# save/RestoreV2_13/shape_and_slices
# save/RestoreV2_13
# save/Assign_13
# save/RestoreV2_14/tensor_names
# save/RestoreV2_14/shape_and_slices
# save/RestoreV2_14
# save/Assign_14
# save/RestoreV2_15/tensor_names
# save/RestoreV2_15/shape_and_slices
# save/RestoreV2_15
# save/Assign_15
# save/RestoreV2_16/tensor_names
# save/RestoreV2_16/shape_and_slices
# save/RestoreV2_16
# save/Assign_16
# save/RestoreV2_17/tensor_names
# save/RestoreV2_17/shape_and_slices
# save/RestoreV2_17
# save/Assign_17
# save/RestoreV2_18/tensor_names
# save/RestoreV2_18/shape_and_slices
# save/RestoreV2_18
# save/Assign_18
# save/RestoreV2_19/tensor_names
# save/RestoreV2_19/shape_and_slices
# save/RestoreV2_19
# save/Assign_19
# save/RestoreV2_20/tensor_names
# save/RestoreV2_20/shape_and_slices
# save/RestoreV2_20
# save/Assign_20
# save/RestoreV2_21/tensor_names
# save/RestoreV2_21/shape_and_slices
# save/RestoreV2_21
# save/Assign_21
# save/RestoreV2_22/tensor_names
# save/RestoreV2_22/shape_and_slices
# save/RestoreV2_22
# save/Assign_22
# save/RestoreV2_23/tensor_names
# save/RestoreV2_23/shape_and_slices
# save/RestoreV2_23
# save/Assign_23
# save/RestoreV2_24/tensor_names
# save/RestoreV2_24/shape_and_slices
# save/RestoreV2_24
# save/Assign_24
# save/RestoreV2_25/tensor_names
# save/RestoreV2_25/shape_and_slices
# save/RestoreV2_25
# save/Assign_25
# save/RestoreV2_26/tensor_names
# save/RestoreV2_26/shape_and_slices
# save/RestoreV2_26
# save/Assign_26
# save/RestoreV2_27/tensor_names
# save/RestoreV2_27/shape_and_slices
# save/RestoreV2_27
# save/Assign_27
# save/RestoreV2_28/tensor_names
# save/RestoreV2_28/shape_and_slices
# save/RestoreV2_28
# save/Assign_28
# save/RestoreV2_29/tensor_names
# save/RestoreV2_29/shape_and_slices
# save/RestoreV2_29
# save/Assign_29
# save/RestoreV2_30/tensor_names
# save/RestoreV2_30/shape_and_slices
# save/RestoreV2_30
# save/Assign_30
# save/RestoreV2_31/tensor_names
# save/RestoreV2_31/shape_and_slices
# save/RestoreV2_31
# save/Assign_31
# save/restore_all
# init
# IteratorGetNext
# IteratorGetNext_1
# IteratorGetNext_2
# IteratorGetNext_3
# IteratorGetNext_4
# IteratorGetNext_5
# IteratorGetNext_6
# IteratorGetNext_7
# IteratorGetNext_8
# IteratorGetNext_9
# IteratorGetNext_10
# IteratorGetNext_11
# IteratorGetNext_12
# IteratorGetNext_13
# IteratorGetNext_14
# IteratorGetNext_15
# IteratorGetNext_16
# IteratorGetNext_17
# IteratorGetNext_18
# IteratorGetNext_19
# IteratorGetNext_20
# IteratorGetNext_21
# IteratorGetNext_22
# IteratorGetNext_23
# IteratorGetNext_24
# IteratorGetNext_25
# IteratorGetNext_26
# IteratorGetNext_27
# IteratorGetNext_28
# IteratorGetNext_29
# IteratorGetNext_30
# IteratorGetNext_31
# IteratorGetNext_32
# IteratorGetNext_33
# IteratorGetNext_34
# IteratorGetNext_35
# IteratorGetNext_36
# IteratorGetNext_37
# IteratorGetNext_38
# IteratorGetNext_39
# IteratorGetNext_40
# IteratorGetNext_41
# IteratorGetNext_42
# IteratorGetNext_43
# IteratorGetNext_44
# IteratorGetNext_45
# IteratorGetNext_46
# IteratorGetNext_47
# IteratorGetNext_48
# IteratorGetNext_49
# IteratorGetNext_50
# IteratorGetNext_51
# IteratorGetNext_52
# IteratorGetNext_53
# IteratorGetNext_54
# IteratorGetNext_55
# IteratorGetNext_56
# IteratorGetNext_57
# IteratorGetNext_58
# IteratorGetNext_59
# IteratorGetNext_60
# IteratorGetNext_61
# IteratorGetNext_62
# IteratorGetNext_63
# IteratorGetNext_64
# IteratorGetNext_65
# IteratorGetNext_66
# IteratorGetNext_67
# IteratorGetNext_68
# IteratorGetNext_69
# IteratorGetNext_70
# IteratorGetNext_71
# IteratorGetNext_72
# IteratorGetNext_73
# IteratorGetNext_74
# IteratorGetNext_75
# IteratorGetNext_76
# IteratorGetNext_77
# IteratorGetNext_78
# IteratorGetNext_79
# IteratorGetNext_80
# IteratorGetNext_81
# IteratorGetNext_82
# IteratorGetNext_83
# IteratorGetNext_84
# IteratorGetNext_85
# IteratorGetNext_86
# IteratorGetNext_87
# IteratorGetNext_88
# IteratorGetNext_89
# IteratorGetNext_90
# IteratorGetNext_91
# IteratorGetNext_92
# IteratorGetNext_93
# IteratorGetNext_94
# IteratorGetNext_95
# IteratorGetNext_96
# IteratorGetNext_97
# IteratorGetNext_98
# IteratorGetNext_99
# IteratorGetNext_100
# IteratorGetNext_101
# IteratorGetNext_102
# IteratorGetNext_103
# IteratorGetNext_104
# IteratorGetNext_105
# IteratorGetNext_106
# IteratorGetNext_107
# IteratorGetNext_108
# IteratorGetNext_109
# IteratorGetNext_110
# IteratorGetNext_111
# IteratorGetNext_112
# IteratorGetNext_113
# IteratorGetNext_114
# IteratorGetNext_115
# IteratorGetNext_116
# IteratorGetNext_117
# IteratorGetNext_118
# IteratorGetNext_119
# IteratorGetNext_120
# IteratorGetNext_121
# IteratorGetNext_122
# IteratorGetNext_123
# IteratorGetNext_124
# IteratorGetNext_125
# IteratorGetNext_126
# IteratorGetNext_127
# IteratorGetNext_128
# IteratorGetNext_129
# IteratorGetNext_130
# IteratorGetNext_131
# IteratorGetNext_132
# IteratorGetNext_133
# IteratorGetNext_134
# IteratorGetNext_135
# IteratorGetNext_136
# IteratorGetNext_137
# IteratorGetNext_138
# IteratorGetNext_139
# IteratorGetNext_140
# IteratorGetNext_141
# IteratorGetNext_142
# IteratorGetNext_143
# IteratorGetNext_144
# IteratorGetNext_145
# IteratorGetNext_146
# IteratorGetNext_147
# IteratorGetNext_148
# IteratorGetNext_149
# IteratorGetNext_150
# IteratorGetNext_151
# IteratorGetNext_152
# IteratorGetNext_153
# IteratorGetNext_154
# IteratorGetNext_155
# IteratorGetNext_156
# IteratorGetNext_157
# IteratorGetNext_158
# IteratorGetNext_159
# IteratorGetNext_160
# IteratorGetNext_161
# IteratorGetNext_162
# IteratorGetNext_163
# IteratorGetNext_164
# IteratorGetNext_165
# IteratorGetNext_166
# IteratorGetNext_167
# IteratorGetNext_168
# IteratorGetNext_169
# IteratorGetNext_170
# IteratorGetNext_171
# IteratorGetNext_172
# IteratorGetNext_173
# IteratorGetNext_174
# IteratorGetNext_175
# IteratorGetNext_176
# IteratorGetNext_177
# IteratorGetNext_178
# IteratorGetNext_179
# IteratorGetNext_180
# IteratorGetNext_181
# IteratorGetNext_182
# IteratorGetNext_183
# IteratorGetNext_184
# IteratorGetNext_185
# IteratorGetNext_186
# IteratorGetNext_187
# IteratorGetNext_188
# IteratorGetNext_189
# IteratorGetNext_190
# IteratorGetNext_191
# IteratorGetNext_192
# IteratorGetNext_193
# IteratorGetNext_194
# IteratorGetNext_195
# IteratorGetNext_196
# IteratorGetNext_197
# IteratorGetNext_198
# IteratorGetNext_199
# IteratorGetNext_200
# IteratorGetNext_201
# IteratorGetNext_202
# IteratorGetNext_203
# IteratorGetNext_204
# IteratorGetNext_205
# IteratorGetNext_206
# IteratorGetNext_207
# IteratorGetNext_208
# IteratorGetNext_209
# IteratorGetNext_210
# IteratorGetNext_211
# IteratorGetNext_212
# IteratorGetNext_213
# IteratorGetNext_214
# IteratorGetNext_215
# IteratorGetNext_216
# IteratorGetNext_217
# IteratorGetNext_218
# IteratorGetNext_219
# IteratorGetNext_220
# IteratorGetNext_221
# IteratorGetNext_222
# IteratorGetNext_223
# IteratorGetNext_224
# IteratorGetNext_225
# IteratorGetNext_226
# IteratorGetNext_227
# IteratorGetNext_228
# IteratorGetNext_229
# IteratorGetNext_230
# IteratorGetNext_231
# IteratorGetNext_232
# IteratorGetNext_233
# IteratorGetNext_234
# IteratorGetNext_235
# IteratorGetNext_236
# IteratorGetNext_237
# IteratorGetNext_238
# IteratorGetNext_239
# IteratorGetNext_240
# IteratorGetNext_241
# IteratorGetNext_242
# IteratorGetNext_243
# IteratorGetNext_244
# IteratorGetNext_245
# IteratorGetNext_246
# IteratorGetNext_247
# IteratorGetNext_248
# IteratorGetNext_249
# IteratorGetNext_250
# IteratorGetNext_251
# IteratorGetNext_252
# IteratorGetNext_253
# IteratorGetNext_254
# IteratorGetNext_255
# IteratorGetNext_256
# IteratorGetNext_257
# IteratorGetNext_258
# IteratorGetNext_259
# IteratorGetNext_260
# IteratorGetNext_261
# IteratorGetNext_262
# IteratorGetNext_263
# IteratorGetNext_264
# IteratorGetNext_265
# IteratorGetNext_266
# IteratorGetNext_267
# IteratorGetNext_268
# IteratorGetNext_269
# IteratorGetNext_270
# IteratorGetNext_271
# IteratorGetNext_272
# IteratorGetNext_273
# IteratorGetNext_274
# IteratorGetNext_275
# IteratorGetNext_276
# IteratorGetNext_277
# IteratorGetNext_278
# IteratorGetNext_279
# IteratorGetNext_280
# IteratorGetNext_281
# IteratorGetNext_282
# IteratorGetNext_283
# IteratorGetNext_284
# IteratorGetNext_285
# IteratorGetNext_286
# IteratorGetNext_287
# IteratorGetNext_288
# IteratorGetNext_289
# IteratorGetNext_290
# IteratorGetNext_291
# IteratorGetNext_292
# IteratorGetNext_293
# IteratorGetNext_294
# IteratorGetNext_295
# IteratorGetNext_296
# IteratorGetNext_297
# IteratorGetNext_298
# IteratorGetNext_299
# IteratorGetNext_300
# IteratorGetNext_301
# IteratorGetNext_302
# IteratorGetNext_303
# IteratorGetNext_304
# IteratorGetNext_305
# IteratorGetNext_306
# IteratorGetNext_307
# IteratorGetNext_308
# IteratorGetNext_309
# IteratorGetNext_310
# IteratorGetNext_311
# IteratorGetNext_312
# IteratorGetNext_313
# IteratorGetNext_314
# IteratorGetNext_315
# IteratorGetNext_316
# IteratorGetNext_317
# IteratorGetNext_318
# IteratorGetNext_319
# IteratorGetNext_320
# IteratorGetNext_321
# IteratorGetNext_322
# IteratorGetNext_323
# IteratorGetNext_324
# IteratorGetNext_325
# IteratorGetNext_326
# IteratorGetNext_327
# IteratorGetNext_328
# IteratorGetNext_329
# IteratorGetNext_330
# IteratorGetNext_331
# IteratorGetNext_332
# IteratorGetNext_333
# IteratorGetNext_334
# IteratorGetNext_335
# IteratorGetNext_336
# IteratorGetNext_337
# IteratorGetNext_338
# IteratorGetNext_339
# IteratorGetNext_340
# IteratorGetNext_341
# IteratorGetNext_342
# IteratorGetNext_343
# IteratorGetNext_344
# IteratorGetNext_345
# IteratorGetNext_346
# IteratorGetNext_347
# IteratorGetNext_348
# IteratorGetNext_349
# IteratorGetNext_350
# IteratorGetNext_351
# IteratorGetNext_352
# IteratorGetNext_353
# IteratorGetNext_354
# IteratorGetNext_355
# IteratorGetNext_356
# IteratorGetNext_357
# IteratorGetNext_358
# IteratorGetNext_359
# IteratorGetNext_360
# IteratorGetNext_361
# IteratorGetNext_362
# IteratorGetNext_363
# IteratorGetNext_364
# IteratorGetNext_365
# IteratorGetNext_366
# IteratorGetNext_367
# IteratorGetNext_368
# IteratorGetNext_369
# IteratorGetNext_370
# IteratorGetNext_371
# IteratorGetNext_372
# IteratorGetNext_373
# IteratorGetNext_374
# IteratorGetNext_375
# IteratorGetNext_376
# IteratorGetNext_377
# IteratorGetNext_378
# IteratorGetNext_379
# IteratorGetNext_380
# IteratorGetNext_381
# IteratorGetNext_382
# IteratorGetNext_383
# IteratorGetNext_384
# IteratorGetNext_385
# IteratorGetNext_386
# IteratorGetNext_387
# IteratorGetNext_388
# IteratorGetNext_389
# IteratorGetNext_390
# IteratorGetNext_391
# IteratorGetNext_392
# IteratorGetNext_393
# IteratorGetNext_394
# IteratorGetNext_395
# IteratorGetNext_396
# IteratorGetNext_397
# IteratorGetNext_398
# IteratorGetNext_399
# INFO:tensorflow:Restoring parameters from ./model/model
# [array([[1.0000000e+00, 8.6641739e-06, 1.1919828e-13]], dtype=float32)]
# [1. 0. 0.]
