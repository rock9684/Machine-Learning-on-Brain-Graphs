# %% [markdown]
# ### 1.4 Search for best hypterparameters

# %%
import numpy as np
import tensorflow as tf
import datetime
import time
import pickle
import matplotlib.pyplot as plt
import os
# %matplotlib inline

# %%
def plot_curves(dic, xlabel, title, legends=None, filename=None, tst=True):
    ''' plot multiple curves
        input: lines: a list of lists lines[i] is a curve indexed by its natural index
               xlabel, ylabel: the name of the axis
               title: title shown on top
               legends: the name of the curves
               filename: if exists then save to directory
    '''

    plt.figure(1, figsize=(15, 5))
    
    if tst is False:
        line_loss = [dic['trn_loss'], dic['val_loss']]
        line_acc = [dic['trn_acc'], dic['val_acc']]
    else:
        line_loss = [dic['trn_loss'], dic['val_loss'], dic['tst_loss']]
        line_acc = [dic['trn_acc'], dic['val_acc'], dic['tst_acc']]
        
    for i in range(len(line_loss)):
        line_i = line_loss[i]
        x = list(range(len(line_i)))
        ax1 = plt.subplot(121)
        ax1.plot(x, line_i, label=legends[i])
        
        plt.title(title + ' (Loss)')
        plt.legend(shadow=True, fancybox=True)
        plt.xlabel(xlabel)
        plt.ylabel('Loss')
    
    for i in range(len(line_acc)):
        line_i = line_acc[i]
        x = list(range(len(line_i)))
        ax2 = plt.subplot(122)
        ax2.plot(x, line_i, label=legends[i])
        
        plt.title(title + ' (Accuracy)')
        plt.legend(shadow=True, fancybox=True)
        plt.xlabel(xlabel)
        plt.ylabel('Accuracy')
    
    plt.savefig(filename + '.pdf')
    return

# %%
with open('./result.p', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    res = u.load()
    
plot_curves(res,
           'Epoch',
           'Result',
           legends=['TRN', 'VAL'], filename='modelb_loss_acc', tst=False)
# Out:
# D:\Apps\Anaconda\envs\tensorflow\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
print('{0:.6f}'.format(res['trn_loss'][-1]))
print('{0:.6f}'.format(res['val_loss'][-1]))
print()
print('{0:.6f}'.format(res['trn_acc'][-1]))
print('{0:.6f}'.format(res['val_acc'][-1]))
# Out:
# 0.697224
# 0.693601
#
# 0.510000
# 0.435000

# %%
with open('./model_1_9/result.p', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    res_1_9 = u.load()
with open('./model_1_8/result.p', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    res_1_8 = u.load()
with open('./model_1_7/result.p', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    res_1_7 = u.load()
with open('./model_1_6/result.p', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    res_1_6 = u.load()
with open('./model_1_5/result.p', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    res_1_5 = u.load()
with open('./model_1_4/result.p', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    res_1_4 = u.load()
with open('./model_1_3/result.p', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    res_1_3 = u.load()
with open('./model_1_2/result.p', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    res_1_2 = u.load()
with open('./model_1_15/result.p', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    res_1_15 = u.load()
with open('./model_1_125/result.p', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    res_1_125 = u.load()
with open('./model_1_1125/result.p', 'rb') as f:
    u = pickle._Unpickler(f)
    u.encoding = 'latin1'
    res_1_1125 = u.load()

acc_1_9, acc_1_8, acc_1_7, acc_1_6, acc_1_5, acc_1_4, acc_1_3, acc_1_2, acc_1_15, acc_1_125, acc_1_1125 = \
res_1_9['val_acc'][-1], res_1_8['val_acc'][-1], res_1_7['val_acc'][-1], res_1_6['val_acc'][-1], res_1_5['val_acc'][-1], res_1_4['val_acc'][-1], res_1_3['val_acc'][-1], res_1_2['val_acc'][-1], res_1_15['val_acc'][-1], res_1_125['val_acc'][-1], res_1_1125['val_acc'][-1]

y = [acc_1_9, acc_1_8, acc_1_7, acc_1_6, acc_1_5, acc_1_4, acc_1_3, acc_1_2, acc_1_15, acc_1_125, acc_1_1125]
x = [0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.15, 0.125, 0.1125]

plt.figure(1, figsize=(15, 5))

plt.plot(x, y)
        
plt.title('MLP performance on different pws_2 when pws_1 is fixed to 0.1')
plt.legend(shadow=True, fancybox=True)
plt.xlabel('pws_2')
plt.ylabel('Accuracy')
        
plt.savefig('MLP_performance_on_different_pws_2' + '.pdf')
# Out:
# No handles with labels found to put in legend.
